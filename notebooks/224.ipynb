# %%
sqs = {}
for i in range(1, 100_000):
    sqs[i**2] = i

# %%
from tqdm.notebook import trange

# %%
#

# %%
from collections import Counter

# %%
int(360**0.5) * int(360**0.5+2)
# Out:
# 360

# %%
mac = 0
ma = 0
ss = set()
CC = Counter()
subs = set()
t = set()
N = 10_000
for a in trange(1, 5000):
    for b in range(a, 5000):
        csq = a**2 + b**2 + 1
        if csq in sqs:
            c = sqs[csq]
            # print(a, b, c)
            if a <= b <= c and a + b + c <= N:
                t.add((a, b, c))
            print(a, b, c, a**2 + b**2, )
# len(ss), subs
len(t)
# Out:
#   0%|          | 0/4999 [00:00<?, ?it/s]
# 2 2 3 8
# 4 8 9 80
# 6 18 19 360
# 8 32 33 1088
# 10 50 51 2600
# 12 12 17 288
# 12 72 73 5328
# 14 98 99 9800
# 16 128 129 16640
# 18 30 35 1224
# 18 162 163 26568
# 20 200 201 40400
# 22 46 51 2600
# 22 242 243 59048
# 24 288 289 83520
# 26 338 339 114920
# 28 76 81 6560
# 28 392 393 154448
# 30 450 451 203400
# 32 100 105 11024
# 32 512 513 263168
# 34 38 51 2600
# 34 578 579 335240
# 36 648 649 421200
# 38 142 147 21608
# 38 722 723 522728
# 40 800 801 641600
# 42 174 179 32040
# 42 882 883 779688
# 44 68 81 6560
# 44 968 969 938960
# 46 1058 1059 1121480
# 48 228 233 54288
# 48 1152 1153 1329408
# 50 1250 1251 1565000
# 52 268 273 74528
# 52 1352 1353 1830608
# 54 1458 1459 2128680
# 56 1568 1569 2461760
# 58 334 339 114920
# 58 1682 1683 2832488
# 60 132 145 21024
# 60 1800 1801 3243600
# 62 382 387 149768
# 62 1922 1923 3697928
# 64 112 129 16640
# 64 2048 2049 4198400
# 66 2178 2179 4748040
# 68 80 105 11024
# 68 460 465 216224
# ...

# %%
len(subs)
# Out:
# 124

# %%
d = {}
for e, a, b, c in subs:
    if e not in d:
        d[e] = []
    d[e].append((a, b, c))

# %%
A, B, C = 1282, 4778, 4947
print(pfs(A), pfs(B), pfs(C))
k = 2
A / k, B / k
# Out:
# [2, 641] [2, 2389] [3, 17, 97]
# (641.0, 2389.0)

# %%
for e in d:
    print(e)
    for q in sorted(d[e]):
        print('\t', q)
# Out:
# 85
# 	 (208, 212, 297)
# 	 (242, 302, 387)
# 	 (268, 380, 465)
# 	 (302, 494, 579)
# 	 (378, 798, 883)
# 	 (412, 956, 1041)
# 	 (438, 1086, 1171)
# 	 (472, 1268, 1353)
# 	 (548, 1724, 1809)
# 	 (582, 1950, 2035)
# 	 (608, 2132, 2217)
# 	 (642, 2382, 2467)
# 	 (718, 2990, 3075)
# 	 (752, 3284, 3369)
# 	 (778, 3518, 3603)
# 	 (812, 3836, 3921)
# 	 (888, 4596, 4681)
# 	 (922, 4958, 5043)
# 	 (948, 5244, 5329)
# 	 (982, 5630, 5715)
# 	 (1058, 6542, 6627)
# 	 (1092, 6972, 7057)
# 	 (1118, 7310, 7395)
# 	 (1152, 7764, 7849)
# 	 (1228, 8828, 8913)
# 	 (1262, 9326, 9411)
# 	 (1288, 9716, 9801)
# 	 (1322, 10238, 10323)
# 	 (1398, 11454, 11539)
# 	 (1432, 12020, 12105)
# 	 (1458, 12462, 12547)
# 	 (1492, 13052, 13137)
# 	 (1568, 14420, 14505)
# 	 (1602, 15054, 15139)
# 	 (1628, 15548, 15633)
# 	 (1662, 16206, 16291)
# 41
# 	 (114, 138, 179)
# 	 (132, 192, 233)
# 	 (196, 448, 489)
# 	 (214, 538, 579)
# 	 (278, 922, 963)
# 	 (296, 1048, 1089)
# 	 (360, 1560, 1601)
# 	 (378, 1722, 1763)
# ...

# %%
5, 1
3, 2

# %%
2 * 2 + 1
# Out:
# 5

# %%
for e, a, b, c in subs:
    print(c - 1, pfs(c - 1))
# Out:
# 338 [2, 13, 13]
# 3314 [2, 1657]
# 296 [2, 2, 2, 37]
# 576 [2, 2, 2, 2, 2, 2, 3, 3]
# 962 [2, 13, 37]
# 1800 [2, 2, 2, 3, 3, 5, 5]
# 4082 [2, 13, 157]
# 272 [2, 2, 2, 2, 17]
# 1730 [2, 5, 173]
# 578 [2, 17, 17]
# 520 [2, 2, 2, 5, 13]
# 610 [2, 5, 61]
# 50 [2, 5, 5]
# 6658 [2, 3329]
# 1088 [2, 2, 2, 2, 2, 2, 17]
# 2960 [2, 2, 2, 2, 5, 37]
# 3688 [2, 2, 2, 461]
# 386 [2, 193]
# 232 [2, 2, 2, 29]
# 1618 [2, 809]
# 898 [2, 449]
# 2448 [2, 2, 2, 2, 3, 3, 17]
# 1544 [2, 2, 2, 193]
# 520 [2, 2, 2, 5, 13]
# 818 [2, 409]
# 6152 [2, 2, 2, 769]
# 6352 [2, 2, 2, 2, 397]
# 848 [2, 2, 2, 2, 53]
# 1394 [2, 17, 41]
# 482 [2, 241]
# 578 [2, 17, 17]
# 5666 [2, 2833]
# 200 [2, 2, 2, 5, 5]
# 3922 [2, 37, 53]
# 178 [2, 89]
# 146 [2, 73]
# 1040 [2, 2, 2, 2, 5, 13]
# 144 [2, 2, 2, 2, 3, 3]
# 1040 [2, 2, 2, 2, 5, 13]
# 2824 [2, 2, 2, 353]
# 5858 [2, 29, 101]
# 648 [2, 2, 2, 3, 3, 3, 3]
# 674 [2, 337]
# 776 [2, 2, 2, 97]
# 848 [2, 2, 2, 2, 53]
# 1168 [2, 2, 2, 2, 73]
# 4754 [2, 2377]
# 610 [2, 5, 61]
# ...

# %%
def pfs(n):
    pfs = []
    for i in range(2, n):
        if i * i > n:
            break
        while n % i == 0:
            n //= i
            pfs.append(i)
    if n - 1:
        pfs.append(n)
    return pfs

# %%
# Out:
# 4.0

# %%
for e in t:
    if e not in triangles:
        print("NOT IN", e)
        break
# Out:
# NOT IN (796, 2852, 2961)

# %%
from tqdm import trange

def get_lower_divs(n):
    mnum = int(n**0.5 + 1)
    divs = []
    for i in range(1, mnum, 2):
        if n % i == 0:
            divs.append(i)
    return divs

triangles = set()
N = 200
for a in trange(2, N // 3 + 1, 2):
    num = a * a + 1
    divs = get_lower_divs(num)
    for d in divs:
        od = num // d
        c = (d + od) // 2
        # print(d, od)
        # print("C", c)
        b = od - c
        # print(d, num, od, a, b, c)
        if a <= b <= c and a + b + c <= N and a**2 + b**2 == c**2 - 1:
            triangles.add((a, b, c))
            # C += 1
# triangles
len(triangles)
# Out:
# 100%|██████████| 33/33 [00:00<00:00, 188829.51it/s]
# 12

# %%
"""


4a^2 + 4b^2 = (2c + 1)^2 - 1
4a^2 + 4b^2 = 4c^2 + 4c + 1 - 1

a^2 + b^2 = c^2 + c
a^2 + b^2 = c(c + 1)


a^2 + 1 = c^2 - b^2
a^2 + 1 = (c + b) (c - b)





"""

# %%
def mult(A, B):
    res = [[0 for _ in range(len(B[0]))] for _ in range(len(A))]
    assert(len(A[0]) == len(B))
    for i in range(len(A)):
        for q in range(len(B[0])):
            for j in range(len(B)):
                res[i][q] += A[i][j] * B[j][q]
    return res

# %%
18**2 + 30**2, 35**2 - 1
# Out:
# (1224, 1224)

# %%
A, B, C = mult([[8, 4, 9]], B)[0]
A**2 + B**2, C**2 - 1
# Out:
# (2600, 2600)

# %%
mult([[2, 2, 3]], A)
# Out:
# [[4, 8, 9]]

# %%
md = 0
for e in tris:
    if e not in triangles:
        md = max(e[2] - e[1], md)
        print(e)
md
# Out:
# (140, 4876, 4878)
# (112, 416, 428)
# (124, 3820, 3822)
# (1848, 1848, 2192)
# (600, 2232, 2296)
# (80, 1576, 1578)
# (120, 3576, 3578)
# (16, 40, 42)
# (20, 76, 78)
# (128, 4072, 4074)
# (184, 1304, 1316)
# (60, 876, 878)
# (116, 3340, 3342)
# (132, 4332, 4334)
# (100, 2476, 2478)
# (48, 552, 554)
# (232, 2136, 2148)
# (68, 1132, 1134)
# (104, 2680, 2682)
# (304, 3744, 3756)
# (112, 3112, 3114)
# (32, 232, 234)
# (84, 1740, 1742)
# (88, 1912, 1914)
# (136, 4600, 4602)
# (24, 120, 122)
# (160, 960, 972)
# (28, 172, 174)
# (72, 1272, 1274)
# (36, 300, 302)
# (108, 2892, 2894)
# (76, 1420, 1422)
# (12, 12, 14)
# (208, 1696, 1708)
# (96, 2280, 2282)
# (64, 1000, 1002)
# (40, 376, 378)
# (44, 460, 462)
# (472, 1160, 1224)
# (92, 2092, 2094)
# (56, 760, 762)
# (280, 3160, 3172)
# (88, 216, 228)
# (136, 664, 676)
# (728, 3560, 3624)
# (328, 4376, 4388)
# (64, 64, 76)
# (344, 344, 408)
# (256, 2624, 2636)
# (52, 652, 654)
# 344

# %%
mult([[0, 0, 1]], A)
# Out:
# [[2, 2, 3]]

# %%
A = [
    [1, 2, 2],
    [-2, -1, -2],
    [2, 2, 3],
]
B = [
    [1, 2, 2],
    [2, 1, 2],
    [2, 2, 3],
]
C = [
    [-1, -2, -2],
    [2, 1, 2],
    [2, 2, 3],
]

N = 75_000_00
tris = set()
st = [[[0, 0, 1]]]
while len(st):
    # print(st)
    c = st.pop()
    tris.add(tuple(c[0]))
    # print(c)
    c[0][0], c[0][1] = c[0][1], c[0][0]
    for el in [A, B, C]:
        t = mult(c, el)
        # print('\t', t)
        if t[0][0] > t[0][1]:
            t[0][0], t[0][1] = t[0][1], t[0][0]
        if sum(t[0]) <= N:
            if t[0][0] >= 1 and t[0][0] <= t[0][1] <= t[0][2]:
                st.append(t)
len(tris)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[183], line 11
#       9 c[0][0], c[0][1] = c[0][1], c[0][0]
#      10 for el in [A, B, C]:
# ---> 11     t = mult(c, el)
#      12     # print('\t', t)
#      13     if t[0][0] > t[0][1]:
#
# Cell In[60], line 6, in mult(A, B)
#       4 for i in range(len(A)):
#       5     for q in range(len(B[0])):
# ----> 6         for j in range(len(B)):
#       7             res[i][q] += A[i][j] * B[j][q]
#       8 return res
#
# KeyboardInterrupt:

# %%
triangles
# Out:
# {(2, 2, 3), (4, 8, 9), (6, 18, 19), (8, 32, 33), (12, 12, 17), (18, 30, 35)}

# %%
tris
# Out:
# {(0, 0, 1), (2, 2, 3), (4, 8, 9), (12, 12, 17), (18, 30, 35)}

# %%
for e in tris:
    if e not in triangles:
        print(e)
for e in triangles:
    if e not in tris:
        print(e)
# Out:
# (0, 0, 1)

# %%
# [[0, 0, 1]]
# 	 [[2, 2, 3]]
# 	 [[2, 2, 3]]
# 	 [[2, 2, 3]]
# [[2, 2, 3]]
# 	 [[4, 8, 9]]
# 	 [[12, 12, 17]]
# [[12, 12, 17]]
# 	 [[22, 46, 51]]
# [[22, 46, 51]]
# [[4, 8, 9]]
# 	 [[18, 30, 35]]
# 	 [[34, 38, 51]]
# [[34, 38, 51]]
# [[18, 30, 35]]
# [[2, 2, 3]]
# 	 [[4, 8, 9]]
# 	 [[12, 12, 17]]
# [[12, 12, 17]]
# 	 [[22, 46, 51]]
# [[22, 46, 51]]
# [[4, 8, 9]]
# 	 [[18, 30, 35]]
# 	 [[34, 38, 51]]
# [[34, 38, 51]]
# [[18, 30, 35]]
# [[2, 2, 3]]
# 	 [[4, 8, 9]]
# 	 [[12, 12, 17]]
# [[12, 12, 17]]
# 	 [[22, 46, 51]]
# [[22, 46, 51]]
# [[4, 8, 9]]
# 	 [[18, 30, 35]]
# 	 [[34, 38, 51]]
# [[34, 38, 51]]
# [[18, 30, 35]]

# %%
for e in triangles:
    if e not in tris:
        print(e)
# Out:
# (28, 76, 81)
# (12, 72, 73)
# (8, 32, 33)
# (10, 50, 51)
# (44, 68, 81)
# (6, 18, 19)

# %%
print(tris)
# Out:
# {(2, 2, 3), (30, 18, 35), (0, 0, 1), (12, 12, 17), (8, 4, 9)}

# %%
print(tris)
# Out:
# {(2, 2, 3), (16, 40, 42), (8, 32, 33), (12, 12, 14), (4, 8, 9), (6, 18, 19)}

# %%
triangles
# Out:
# {(2, 2, 3), (4, 8, 9), (6, 18, 19), (8, 32, 33), (12, 12, 17), (18, 30, 35)}

# %%
tris
# Out:
# {(2, 2, 3), (4, 8, 9), (6, 18, 19), (8, 32, 33), (12, 12, 14), (16, 40, 42)}

# %%
for e in tris:
    print(e[0]**2, e[1]**2, e[2]**2, 1)
# Out:
# 4 4 9 1
# 256 1600 1764 1
# 64 1024 1089 1
# 144 144 196 1
# 16 64 81 1
# 36 324 361 1

# %%
len([e for e in tris if e[0]**2+e[1]**2==e[2]**2-1])
# Out:
# 4

# %%
mult(b, C)
# Out:
# [[8, 4, 9]]
